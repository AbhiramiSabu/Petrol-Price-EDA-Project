# %% [markdown]
# # **PETROL PRICE**

# %% [markdown]
# # *This project is based on the petrol price of different states in India within certain year*

# %%
# Importing data sets
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# plt.style.use('dark_background')

# %%
# reading the data
data=pd.read_csv("/content/petrol_price.csv")

# %% [markdown]
# # Preliminary Analysis of Data

# %% [markdown]
# *This includes the data cleaning process, extration and certain statistical functions applied on the dataset*

# %%
data.head()     # values from top of the data
# Out:
#    date month  Maharashtra   Haryana  Delhi  Gujarat  Karnataka  Telangana  \
# 0  2017   Aug        74.56     64.98  65.40    67.09      66.39      69.24
# 1  2017   Dec        76.52     68.78  69.22    68.06      70.29      73.29
# 2  2017   Jul        74.30     62.68  63.09    64.77      64.24      67.02
# 3  2017   Jun        78.44     66.70  66.91    68.91      71.59      71.49
# 4  2017   May        77.46     67.84  68.09    71.15      73.01      72.68
#
#    Rajasthan  Punjab  West_bengal  Tamil Nadu   Uttar Pradesh  Madhya Pradesh  \
# 0      67.93   70.32        68.56       67.71           68.63           71.99
# 1      71.83   74.21        71.98       71.74           71.58           73.93
# 2      65.77   67.93        66.14       65.46           66.53           69.62
# 3      69.88   72.51        69.52       69.93           69.86           74.65
# 4      71.12   73.41        70.68       71.17           70.74           75.87
#
#    Kerala  Assam  Bihar
# ...

# %%
data.tail()      #  values from the bottom of the data
# Out:
#     date month  Maharashtra   Haryana   Delhi  Gujarat  Karnataka  Telangana  \
# 62  2022   Jun        97.28     90.27   89.62    92.38      87.89      97.82
# 63  2022   Mar       109.98     95.27   95.41    95.35     100.58     108.20
# 64  2022   May       120.51    106.15  105.41   105.29     111.09     119.49
# 65  2022   Oct       106.31     97.43   96.72    96.63     101.94     109.66
# 66  2022   Sep       106.31     97.43   96.72    96.63     101.94     109.66
#
#     Rajasthan  Punjab  West_bengal  Tamil Nadu   Uttar Pradesh  \
# 62      93.72   86.55        92.76       94.24           89.76
# 63     107.06   94.94       104.67      101.40           95.28
# 64     118.03  104.56       115.12      110.85          105.25
# 65     108.48   96.18       106.03      102.63           96.57
# 66     108.48   96.18       106.03      102.63           96.57
#
#     Madhya Pradesh  Kerala   Assam   Bihar
# 62           93.90   96.52   83.94   94.04
# ...

# %%
data.describe()
# Out:
#               date  Maharashtra     Haryana       Delhi     Gujarat  \
# count    67.000000    67.000000   67.000000   67.000000   67.000000
# mean   2019.611940    89.094030   80.561343   81.278209   79.951343
# std       1.641832    13.338161   11.747156   12.036261   11.988457
# min    2017.000000    74.300000   62.680000   63.090000   64.770000
# 25%    2018.000000    78.350000   71.390000   71.595000   70.210000
# 50%    2020.000000    83.760000   76.520000   76.310000   75.680000
# 75%    2021.000000    99.145000   91.025000   92.830000   92.030000
# max    2022.000000   120.510000  106.620000  109.690000  106.530000
#
#         Karnataka   Telangana   Rajasthan      Punjab  West_bengal  \
# count   67.000000   67.000000   67.000000   67.000000    67.000000
# mean    84.020597   86.935672   86.625373   83.088955    84.542836
# std     13.031010   14.264798   15.036667   11.015556    13.359466
# min     64.240000   67.020000   65.770000   67.930000    66.140000
# ...

# %%
data.describe(include= 'object')
# Out:
#        month
# count     67
# unique    12
# top      Aug
# freq       6

# %%
data.isnull().sum()        # finding if any null value
# Out:
# date              0
# month             0
# Maharashtra       0
#  Haryana          0
# Delhi             0
# Gujarat           0
# Karnataka         0
# Telangana         0
# Rajasthan         0
# Punjab            0
# West_bengal       0
# Tamil Nadu        0
#  Uttar Pradesh    0
# Madhya Pradesh    0
# Kerala            0
# Assam             0
# Bihar             0
# dtype: int64

# %%
data.info()             #extracting information of column in the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            67 non-null     int64
#  1   month           67 non-null     object
#  2   Maharashtra     67 non-null     float64
#  3    Haryana        67 non-null     float64
#  4   Delhi           67 non-null     float64
#  5   Gujarat         67 non-null     float64
#  6   Karnataka       67 non-null     float64
#  7   Telangana       67 non-null     float64
#  8   Rajasthan       67 non-null     float64
#  9   Punjab          67 non-null     float64
#  10  West_bengal     67 non-null     float64
#  11  Tamil Nadu      67 non-null     float64
#  12   Uttar Pradesh  67 non-null     float64
#  13  Madhya Pradesh  67 non-null     float64
#  14  Kerala          67 non-null     float64
#  15  Assam           67 non-null     float64
#  16  Bihar           67 non-null     float64
# ...

# %%
data.shape          #shape of the data
# Out:
# (67, 17)

# %%
data.dtypes           #datatypes of each column
# Out:
# date                int64
# month              object
# Maharashtra       float64
#  Haryana          float64
# Delhi             float64
# Gujarat           float64
# Karnataka         float64
# Telangana         float64
# Rajasthan         float64
# Punjab            float64
# West_bengal       float64
# Tamil Nadu        float64
#  Uttar Pradesh    float64
# Madhya Pradesh    float64
# Kerala            float64
# Assam             float64
# Bihar             float64
# dtype: object

# %%
data['date'].unique          #unique values
# Out:
# <bound method Series.unique of 0     2017
# 1     2017
# 2     2017
# 3     2017
# 4     2017
#       ...
# 62    2022
# 63    2022
# 64    2022
# 65    2022
# 66    2022
# Name: date, Length: 67, dtype: int64>

# %%
petrol=data[['date','month']]           #filtering
petrol
# Out:
#     date month
# 0   2017   Aug
# 1   2017   Dec
# 2   2017   Jul
# 3   2017   Jun
# 4   2017   May
# ..   ...   ...
# 62  2022   Jun
# 63  2022   Mar
# 64  2022   May
# 65  2022   Oct
# 66  2022   Sep
#
# [67 rows x 2 columns]

# %%
data[['date','month','Maharashtra']]         #filtering
# Out:
#     date month  Maharashtra
# 0   2017   Aug        74.56
# 1   2017   Dec        76.52
# 2   2017   Jul        74.30
# 3   2017   Jun        78.44
# 4   2017   May        77.46
# ..   ...   ...          ...
# 62  2022   Jun        97.28
# 63  2022   Mar       109.98
# 64  2022   May       120.51
# 65  2022   Oct       106.31
# 66  2022   Sep       106.31
#
# [67 rows x 3 columns]

# %%
data[['date','month',' Haryana']]              #filtering
# Out:
#     date month   Haryana
# 0   2017   Aug     64.98
# 1   2017   Dec     68.78
# 2   2017   Jul     62.68
# 3   2017   Jun     66.70
# 4   2017   May     67.84
# ..   ...   ...       ...
# 62  2022   Jun     90.27
# 63  2022   Mar     95.27
# 64  2022   May    106.15
# 65  2022   Oct     97.43
# 66  2022   Sep     97.43
#
# [67 rows x 3 columns]

# %%
data[['date','month','Delhi']]               #filtering
# Out:
#     date month   Delhi
# 0   2017   Aug   65.40
# 1   2017   Dec   69.22
# 2   2017   Jul   63.09
# 3   2017   Jun   66.91
# 4   2017   May   68.09
# ..   ...   ...     ...
# 62  2022   Jun   89.62
# 63  2022   Mar   95.41
# 64  2022   May  105.41
# 65  2022   Oct   96.72
# 66  2022   Sep   96.72
#
# [67 rows x 3 columns]

# %%
data[['date','month','Gujarat']]               #filtering
# Out:
#     date month  Gujarat
# 0   2017   Aug    67.09
# 1   2017   Dec    68.06
# 2   2017   Jul    64.77
# 3   2017   Jun    68.91
# 4   2017   May    71.15
# ..   ...   ...      ...
# 62  2022   Jun    92.38
# 63  2022   Mar    95.35
# 64  2022   May   105.29
# 65  2022   Oct    96.63
# 66  2022   Sep    96.63
#
# [67 rows x 3 columns]

# %%
data[['date','month','Karnataka']]                   #filtering
# Out:
#     date month  Karnataka
# 0   2017   Aug      66.39
# 1   2017   Dec      70.29
# 2   2017   Jul      64.24
# 3   2017   Jun      71.59
# 4   2017   May      73.01
# ..   ...   ...        ...
# 62  2022   Jun      87.89
# 63  2022   Mar     100.58
# 64  2022   May     111.09
# 65  2022   Oct     101.94
# 66  2022   Sep     101.94
#
# [67 rows x 3 columns]

# %%
data[['date','month','Telangana']]                 #filtering
# Out:
#     date month  Telangana
# 0   2017   Aug      69.24
# 1   2017   Dec      73.29
# 2   2017   Jul      67.02
# 3   2017   Jun      71.49
# 4   2017   May      72.68
# ..   ...   ...        ...
# 62  2022   Jun      97.82
# 63  2022   Mar     108.20
# 64  2022   May     119.49
# 65  2022   Oct     109.66
# 66  2022   Sep     109.66
#
# [67 rows x 3 columns]

# %%
data[['date','month','Rajasthan']]                     #filtering
# Out:
#     date month  Rajasthan
# 0   2017   Aug      67.93
# 1   2017   Dec      71.83
# 2   2017   Jul      65.77
# 3   2017   Jun      69.88
# 4   2017   May      71.12
# ..   ...   ...        ...
# 62  2022   Jun      93.72
# 63  2022   Mar     107.06
# 64  2022   May     118.03
# 65  2022   Oct     108.48
# 66  2022   Sep     108.48
#
# [67 rows x 3 columns]

# %%
data[['date','month','Punjab']]                          #filtering
# Out:
#     date month  Punjab
# 0   2017   Aug   70.32
# 1   2017   Dec   74.21
# 2   2017   Jul   67.93
# 3   2017   Jun   72.51
# 4   2017   May   73.41
# ..   ...   ...     ...
# 62  2022   Jun   86.55
# 63  2022   Mar   94.94
# 64  2022   May  104.56
# 65  2022   Oct   96.18
# 66  2022   Sep   96.18
#
# [67 rows x 3 columns]

# %%
data[['date','month','West_bengal']]               #filtering
# Out:
#     date month  West_bengal
# 0   2017   Aug        68.56
# 1   2017   Dec        71.98
# 2   2017   Jul        66.14
# 3   2017   Jun        69.52
# 4   2017   May        70.68
# ..   ...   ...          ...
# 62  2022   Jun        92.76
# 63  2022   Mar       104.67
# 64  2022   May       115.12
# 65  2022   Oct       106.03
# 66  2022   Sep       106.03
#
# [67 rows x 3 columns]

# %%
data[['date','month','Tamil Nadu']]       #filtering
# Out:
#     date month  Tamil Nadu
# 0   2017   Aug       67.71
# 1   2017   Dec       71.74
# 2   2017   Jul       65.46
# 3   2017   Jun       69.93
# 4   2017   May       71.17
# ..   ...   ...         ...
# 62  2022   Jun       94.24
# 63  2022   Mar      101.40
# 64  2022   May      110.85
# 65  2022   Oct      102.63
# 66  2022   Sep      102.63
#
# [67 rows x 3 columns]

# %%
data[['date','month',' Uttar Pradesh']]        #filtering
# Out:
#     date month   Uttar Pradesh
# 0   2017   Aug           68.63
# 1   2017   Dec           71.58
# 2   2017   Jul           66.53
# 3   2017   Jun           69.86
# 4   2017   May           70.74
# ..   ...   ...             ...
# 62  2022   Jun           89.76
# 63  2022   Mar           95.28
# 64  2022   May          105.25
# 65  2022   Oct           96.57
# 66  2022   Sep           96.57
#
# [67 rows x 3 columns]

# %%
data[['date','month','Madhya Pradesh']]            #filtering
# Out:
#     date month  Madhya Pradesh
# 0   2017   Aug           71.99
# 1   2017   Dec           73.93
# 2   2017   Jul           69.62
# 3   2017   Jun           74.65
# 4   2017   May           75.87
# ..   ...   ...             ...
# 62  2022   Jun           93.90
# 63  2022   Mar          107.23
# 64  2022   May          118.14
# 65  2022   Oct          108.65
# 66  2022   Sep          108.65
#
# [67 rows x 3 columns]

# %%
data[['date','month','Kerala']]        #filtering
# Out:
#     date month  Kerala
# 0   2017   Aug   69.06
# 1   2017   Dec   72.99
# 2   2017   Jul   66.93
# 3   2017   Jun   71.27
# 4   2017   May   72.43
# ..   ...   ...     ...
# 62  2022   Jun   96.52
# 63  2022   Mar  106.36
# 64  2022   May  117.19
# 65  2022   Oct  107.71
# 66  2022   Sep  107.71
#
# [67 rows x 3 columns]

# %%
data[['date','month','Assam']]           #filtering
# Out:
#     date month   Assam
# 0   2017   Aug   68.03
# 1   2017   Dec   71.13
# 2   2017   Jul   65.83
# 3   2017   Jun   70.52
# 4   2017   May   71.41
# ..   ...   ...     ...
# 62  2022   Jun   83.94
# 63  2022   Mar   94.58
# 64  2022   May  105.66
# 65  2022   Oct   96.01
# 66  2022   Sep   96.01
#
# [67 rows x 3 columns]

# %%
data[['date','month','Bihar']]             #filtering
# Out:
#     date month   Bihar
# 0   2017   Aug   69.78
# 1   2017   Dec   73.57
# 2   2017   Jul   65.93
# 3   2017   Jun   69.85
# 4   2017   May   71.16
# ..   ...   ...     ...
# 62  2022   Jun   94.04
# 63  2022   Mar  105.90
# 64  2022   May  116.23
# 65  2022   Oct  107.24
# 66  2022   Sep  107.24
#
# [67 rows x 3 columns]

# %% [markdown]
# # **Statistical Functions**

# %% [markdown]
# Certain statistical functions include maximum, minimum, mean, median, mode, standard deviation, variance

# %%
data[['date','month','Maharashtra']].max()
# Out:
# date             2022
# month             Sep
# Maharashtra    120.51
# dtype: object

# %%
data[['date','Maharashtra']].min()
# Out:
# date           2017.0
# Maharashtra      74.3
# dtype: float64

# %%
data[['date','month',' Haryana']].max()
# Out:
# date          2022
# month          Sep
#  Haryana    106.62
# dtype: object

# %%
data[['date','month',' Haryana']].min()
# Out:
# date         2017
# month         Apr
#  Haryana    62.68
# dtype: object

# %%
data[['date','month','Delhi']].max()
# Out:
# date       2022
# month       Sep
# Delhi    109.69
# dtype: object

# %%
data[['date','month','Delhi']].min()
# Out:
# date      2017
# month      Apr
# Delhi    63.09
# dtype: object

# %%
data[['date','month','Gujarat']].max()
# Out:
# date         2022
# month         Sep
# Gujarat    106.53
# dtype: object

# %%
data[['date','month','Gujarat']].min()
# Out:
# date        2017
# month        Apr
# Gujarat    64.77
# dtype: object

# %%
data[['date','month','Karnataka']].max()
# Out:
# date           2022
# month           Sep
# Karnataka    113.56
# dtype: object

# %%
data[['date','month','Karnataka']].min()
# Out:
# date          2017
# month          Apr
# Karnataka    64.24
# dtype: object

# %%
data[['date','month','Telangana']].max()
# Out:
# date           2022
# month           Sep
# Telangana    119.49
# dtype: object

# %%
data[['date','month','Telangana']].min()
# Out:
# date          2017
# month          Apr
# Telangana    67.02
# dtype: object

# %%
data[['date','month','Rajasthan']].max()
# Out:
# date           2022
# month           Sep
# Rajasthan    118.03
# dtype: object

# %%
data[['date','month','Rajasthan']].min()
# Out:
# date          2017
# month          Apr
# Rajasthan    65.77
# dtype: object

# %%
data[['date','month','Punjab']].max()
# Out:
# date        2022
# month        Sep
# Punjab    110.61
# dtype: object

# %%
data[['date','month','Punjab']].min()
# Out:
# date       2017
# month       Apr
# Punjab    67.93
# dtype: object

# %%
data[['date','month','West_bengal']].max()
# Out:
# date             2022
# month             Sep
# West_bengal    115.12
# dtype: object

# %%
data[['date','month','West_bengal']].min()
# Out:
# date            2017
# month            Apr
# West_bengal    66.14
# dtype: object

# %%
data[['date','month','Tamil Nadu']].max()
# Out:
# date            2022
# month            Sep
# Tamil Nadu    110.85
# dtype: object

# %%
data[['date','month','Tamil Nadu']].min()
# Out:
# date           2017
# month           Apr
# Tamil Nadu    65.46
# dtype: object

# %%
data[['date','month',' Uttar Pradesh']].max()
# Out:
# date                2022
# month                Sep
#  Uttar Pradesh    106.61
# dtype: object

# %%
data[['date','month',' Uttar Pradesh']].min()
# Out:
# date               2017
# month               Apr
#  Uttar Pradesh    66.53
# dtype: object

# %%
data[['date','month','Madhya Pradesh']].max()
# Out:
# date                2022
# month                Sep
# Madhya Pradesh    118.46
# dtype: object

# %%
data[['date','month','Madhya Pradesh']].min()
# Out:
# date               2017
# month               Apr
# Madhya Pradesh    69.62
# dtype: object

# %%
data[['date','month','Kerala']].max()
# Out:
# date        2022
# month        Sep
# Kerala    117.19
# dtype: object

# %%
data[['date','month','Kerala']].min()
# Out:
# date       2017
# month       Apr
# Kerala    66.93
# dtype: object

# %%
data[['date','month','Assam']].max()
# Out:
# date       2022
# month       Sep
# Assam    105.74
# dtype: object

# %%
data[['date','month','Assam']].min()
# Out:
# date      2017
# month      Apr
# Assam    65.83
# dtype: object

# %%
data[['date','month','Bihar']].max()
# Out:
# date       2022
# month       Sep
# Bihar    116.23
# dtype: object

# %%
data[['date','month','Bihar']].min()
# Out:
# date      2017
# month      Apr
# Bihar    65.93
# dtype: object

# %%
data[['Maharashtra']].describe()
# Out:
#        Maharashtra
# count    67.000000
# mean     89.094030
# std      13.338161
# min      74.300000
# 25%      78.350000
# 50%      83.760000
# 75%      99.145000
# max     120.510000

# %%
data[[' Haryana']].describe()
# Out:
#           Haryana
# count   67.000000
# mean    80.561343
# std     11.747156
# min     62.680000
# 25%     71.390000
# 50%     76.520000
# 75%     91.025000
# max    106.620000

# %%
data[['Delhi']].describe()
# Out:
#             Delhi
# count   67.000000
# mean    81.278209
# std     12.036261
# min     63.090000
# 25%     71.595000
# 50%     76.310000
# 75%     92.830000
# max    109.690000

# %%
data[['Gujarat']].describe()
# Out:
#           Gujarat
# count   67.000000
# mean    79.951343
# std     11.988457
# min     64.770000
# 25%     70.210000
# 50%     75.680000
# 75%     92.030000
# max    106.530000

# %%
data[['Karnataka']].describe()
# Out:
#         Karnataka
# count   67.000000
# mean    84.020597
# std     13.031010
# min     64.240000
# 25%     73.745000
# 50%     78.770000
# 75%     95.930000
# max    113.560000

# %%
data[['Telangana']].describe()
# Out:
#         Telangana
# count   67.000000
# mean    86.935672
# std     14.264798
# min     67.020000
# 25%     76.020000
# 50%     80.900000
# 75%     98.010000
# max    119.490000

# %%
data[['Rajasthan']].describe()
# Out:
#         Rajasthan
# count   67.000000
# mean    86.625373
# std     15.036667
# min     65.770000
# 25%     74.170000
# 50%     79.260000
# 75%     99.370000
# max    118.030000

# %%
data[['Punjab']].describe()
# Out:
#            Punjab
# count   67.000000
# mean    83.088955
# std     11.015556
# min     67.930000
# 25%     73.510000
# 50%     81.490000
# 75%     93.540000
# max    110.610000

# %%
data[['West_bengal']].describe()
# Out:
#        West_bengal
# count    67.000000
# mean     84.542836
# std      13.359466
# min      66.140000
# 25%      74.030000
# 50%      79.200000
# 75%      93.630000
# max     115.120000

# %%
data[['Tamil Nadu']].describe()
# Out:
#        Tamil Nadu
# count   67.000000
# mean    84.281940
# std     12.260133
# min     65.460000
# 25%     74.480000
# 50%     79.260000
# 75%     95.115000
# max    110.850000

# %%
data[['Madhya Pradesh']].describe()
# Out:
#        Madhya Pradesh
# count       67.000000
# mean        88.570597
# std         14.080720
# min         69.620000
# 25%         77.070000
# 50%         83.220000
# 75%        100.910000
# max        118.460000

# %%
data[['Kerala']].describe()
# Out:
#            Kerala
# count   67.000000
# mean    85.668657
# std     13.778086
# min     66.930000
# 25%     75.025000
# 50%     79.470000
# 75%     96.495000
# max    117.190000

# %%
data[[' Uttar Pradesh']].describe()
# Out:
#         Uttar Pradesh
# count       67.000000
# mean        81.551045
# std         10.898700
# min         66.530000
# 25%         72.150000
# 50%         77.110000
# 75%         90.705000
# max        106.610000

# %%
data[['Assam']].describe()
# Out:
#             Assam
# count   67.000000
# mean    82.019254
# std     10.526686
# min     65.830000
# 25%     72.530000
# 50%     78.510000
# 75%     89.600000
# max    105.740000

# %%
data[['Bihar']].describe()
# Out:
#             Bihar
# count   67.000000
# mean    86.291343
# std     13.352867
# min     65.930000
# 25%     75.995000
# 50%     82.050000
# 75%     95.340000
# max    116.230000

# %%
data.median()
# Out:
# <ipython-input-701-135339ac59ce>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# date              2020.00
# Maharashtra         83.76
#  Haryana            76.52
# Delhi               76.31
# Gujarat             75.68
# Karnataka           78.77
# Telangana           80.90
# Rajasthan           79.26
# Punjab              81.49
# West_bengal         79.20
# Tamil Nadu          79.26
#  Uttar Pradesh      77.11
# Madhya Pradesh      83.22
# Kerala              79.47
# Assam               78.51
# Bihar               82.05
# dtype: float64

# %%
data.mode()
# Out:
#      date month  Maharashtra   Haryana  Delhi  Gujarat  Karnataka  Telangana  \
# 0  2018.0   Aug       106.31     97.43  96.72    96.63     101.94     109.66
# 1  2019.0   Dec       109.98       NaN    NaN      NaN        NaN        NaN
# 2  2020.0   Jul          NaN       NaN    NaN      NaN        NaN        NaN
# 3  2021.0   Jun          NaN       NaN    NaN      NaN        NaN        NaN
# 4     NaN   May          NaN       NaN    NaN      NaN        NaN        NaN
# 5     NaN   Oct          NaN       NaN    NaN      NaN        NaN        NaN
# 6     NaN   Sep          NaN       NaN    NaN      NaN        NaN        NaN
#
#    Rajasthan  Punjab  West_bengal  Tamil Nadu   Uttar Pradesh  Madhya Pradesh  \
# 0     108.48   96.18       106.03      102.63           96.57          108.65
# 1        NaN     NaN          NaN         NaN             NaN             NaN
# 2        NaN     NaN          NaN         NaN             NaN             NaN
# ...

# %%
data.std()
# Out:
# <ipython-input-703-a47ac8255c06>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# date               1.641832
# Maharashtra       13.338161
#  Haryana          11.747156
# Delhi             12.036261
# Gujarat           11.988457
# Karnataka         13.031010
# Telangana         14.264798
# Rajasthan         15.036667
# Punjab            11.015556
# West_bengal       13.359466
# Tamil Nadu        12.260133
#  Uttar Pradesh    10.898700
# Madhya Pradesh    14.080720
# Kerala            13.778086
# Assam             10.526686
# Bihar             13.352867
# dtype: float64

# %%
data.var()
# Out:
# <ipython-input-704-6bf595b3cfe5>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# date                2.695613
# Maharashtra       177.906546
#  Haryana          137.995675
# Delhi             144.871576
# Gujarat           143.723100
# Karnataka         169.807221
# Telangana         203.484473
# Rajasthan         226.101359
# Punjab            121.342467
# West_bengal       178.475342
# Tamil Nadu        150.310870
#  Uttar Pradesh    118.781655
# Madhya Pradesh    198.266669
# Kerala            189.835648
# Assam             110.811128
# Bihar             178.299054
# dtype: float64

# %%
data.corr()
# Out:
# <ipython-input-705-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                     date  Maharashtra   Haryana     Delhi   Gujarat  \
# date            1.000000     0.813289  0.835578  0.832129  0.804388
# Maharashtra     0.813289     1.000000  0.988121  0.981568  0.991717
#  Haryana        0.835578     0.988121  1.000000  0.995278  0.993697
# Delhi           0.832129     0.981568  0.995278  1.000000  0.991215
# Gujarat         0.804388     0.991717  0.993697  0.991215  1.000000
# Karnataka       0.845546     0.984942  0.993223  0.995442  0.988003
# Telangana       0.843118     0.991557  0.992931  0.981250  0.987630
# Rajasthan       0.867246     0.986590  0.988145  0.988640  0.984679
# Punjab          0.729911     0.967250  0.975421  0.981478  0.980116
# ...

# %%
data.value_counts()
# Out:
# date  month  Maharashtra   Haryana  Delhi  Gujarat  Karnataka  Telangana  Rajasthan  Punjab  West_bengal  Tamil Nadu   Uttar Pradesh  Madhya Pradesh  Kerala  Assam  Bihar
# 2017  Aug    74.56        64.98     65.40  67.09    66.39      69.24      67.93      70.32   68.56        67.71       68.63           71.99           69.06   68.03  69.78     1
# 2021  Jun    100.72       91.78     94.49  91.68    97.64      98.20      101.02     95.65   94.50        95.99       91.65           102.61          96.47   90.20  96.64     1
# 2020  Jan    80.79        74.20     75.14  72.69    77.71      79.96      79.07      75.02   77.79        78.12       76.28           83.43           78.59   77.39  79.83     1
#       Jul    87.19        78.16     80.43  78.08    83.04      83.49      87.57      81.63   82.10        83.63       80.86           88.08           82.15   84.50  83.31     1
# ...

# %% [markdown]
# # **Comparison Operations**

# %%
data_new=pd.DataFrame(data)
data_new.groupby('date')['Maharashtra']

# %%
data_new[data_new['date']==2017]
# Out:
#    date month  Maharashtra   Haryana  Delhi  Gujarat  Karnataka  Telangana  \
# 0  2017   Aug        74.56     64.98  65.40    67.09      66.39      69.24
# 1  2017   Dec        76.52     68.78  69.22    68.06      70.29      73.29
# 2  2017   Jul        74.30     62.68  63.09    64.77      64.24      67.02
# 3  2017   Jun        78.44     66.70  66.91    68.91      71.59      71.49
# 4  2017   May        77.46     67.84  68.09    71.15      73.01      72.68
# 5  2017   Nov        76.25     68.70  69.14    68.37      70.21      73.20
# 6  2017   Oct        79.87     70.31  70.76    72.58      71.87      74.93
# 7  2017   Sep        78.38     68.82  69.26    71.05      70.34      73.34
#
#    Rajasthan  Punjab  West_bengal  Tamil Nadu   Uttar Pradesh  Madhya Pradesh  \
# 0      67.93   70.32        68.56       67.71           68.63           71.99
# 1      71.83   74.21        71.98       71.74           71.58           73.93
# ...

# %%
data_new[data_new['date']==2018]
# Out:
#     date month  Maharashtra   Haryana  Delhi  Gujarat  Karnataka  Telangana  \
# 8   2018   Apr        81.59     73.86  73.73    73.05      74.90      78.08
# 9   2018   Aug        83.76     76.52  76.31    75.68      78.77      80.90
# 10  2018   Dec        78.09     71.06  72.53    70.06      73.09      76.89
# 11  2018   Feb        80.91     73.18  73.05    72.65      74.20      77.36
# 12  2018   Jan        77.87     69.72  69.97    69.38      71.06      74.09
# 13  2018   Jul        82.99     75.67  75.55    74.87      76.77      80.03
# 14  2018   Jun        86.10     78.39  78.29    77.58      79.57      82.94
# 15  2018   Mar        79.45     71.71  71.57    71.18      72.69      75.79
# 16  2018   May        82.48     74.75  74.63    73.94      75.82      79.04
# 17  2018   Nov        84.86     77.70  79.39    76.63      79.99      84.14
# 18  2018   Oct        91.08     83.87  83.73    83.01      84.40      88.77
# ...

# %%
data_new[data_new['date']==2019]
# Out:
#     date month  Maharashtra   Haryana  Delhi  Gujarat  Karnataka  Telangana  \
# 20  2019   Apr        78.43     72.36  72.86    70.39      75.23      77.26
# 21  2019   Aug        78.42     72.32  72.80    70.36      75.21      77.31
# 22  2019   Dec        80.59     74.04  74.91    72.49      77.50      79.74
# 23  2019   Feb        76.57     71.37  70.94    68.58      73.28      75.26
# 24  2019   Jan        74.30     69.56  68.65    66.36      69.21      72.82
# 25  2019   Jul        76.11     70.48  70.44    68.11      72.79      74.83
# 26  2019   Jun        77.28     71.41  71.62    69.25      74.01      76.05
# 27  2019   Mar        77.44     71.74  71.81    69.42      74.20      76.20
# 28  2019   May        78.70     72.58  73.13    70.65      75.51      77.55
# 29  2019   Nov        78.51     72.39  72.86    70.47      75.32      77.51
# 30  2019   Oct        80.21     73.74  74.61    72.12      77.10      79.25
# ...

# %%
data_new[data_new['date']==2020]
# Out:
#     date month  Maharashtra   Haryana  Delhi  Gujarat  Karnataka  Telangana  \
# 32  2020   Apr        75.30     69.84  69.59    67.33      73.55      73.97
# 33  2020   Aug        87.19     78.18  80.43    78.08      83.04      83.49
# 34  2020   Dec        89.02     79.99  82.34    79.96      85.09      85.64
# 35  2020   Feb        78.83     72.64  73.19    70.78      75.66      77.85
# 36  2020   Jan        80.79     74.20  75.14    72.69      77.71      79.96
# 37  2020   Jul        87.19     78.16  80.43    78.08      83.04      83.49
# 38  2020   Jun        78.32     70.85  71.26    67.33      73.55      73.97
# 39  2020   Mar        77.18     71.33  71.49    69.16      73.94      75.99
# 40  2020   May        76.31     69.84  69.59    67.33      73.55      73.97
# 41  2020   Nov        87.74     78.77  81.06    78.66      83.69      84.25
# 42  2020   Oct        87.74     78.74  81.06    78.66      83.69      84.25
# ...

# %%
data_new[data_new['date']==2021]
# Out:
#     date month  Maharashtra   Haryana   Delhi  Gujarat  Karnataka  Telangana  \
# 44  2021   Apr        96.98     88.02   90.56    87.90      93.59      94.16
# 45  2021   Aug       107.83     98.92  101.84    98.79     105.25     105.83
# 46  2021   Dec       109.98     95.27   95.41    95.35     100.58     108.20
# 47  2021   Feb        92.86     83.89   86.30    83.81      89.21      89.77
# 48  2021   Jan        90.34     81.35   83.71    81.29      86.51      87.06
# 49  2021   Jul       104.90     95.97   98.81    95.86     102.11     102.69
# 50  2021   Jun       100.72     91.78   94.49    91.68      97.64      98.20
# 51  2021   Mar        97.57     88.61   91.17    88.49      94.22      94.79
# 52  2021   May        96.83     87.86   90.40    87.75      93.43      93.99
# 53  2021   Nov       115.50    106.62  109.69   106.53     113.56     114.12
# 54  2021   Oct       107.95     99.04  101.89    98.95     105.44     106.00
# ...

# %%
data_new[data_new['date']==2022]
# Out:
#     date month  Maharashtra   Haryana   Delhi  Gujarat  Karnataka  Telangana  \
# 56  2022   Apr       116.72    102.51  101.81   101.70     107.30     115.42
# 57  2022   Aug       106.31     97.43   96.72    96.63     101.94     109.66
# 58  2022   Dec       106.31     97.43   96.72    96.63     101.94     109.66
# 59  2022   Feb       109.98     95.27   95.41    95.35     100.58     108.20
# 60  2022   Jan       109.98     95.27   95.41    95.35     100.58     108.20
# 61  2022   Jul       111.35     97.43   96.72    96.63     101.94     109.66
# 62  2022   Jun        97.28     90.27   89.62    92.38      87.89      97.82
# 63  2022   Mar       109.98     95.27   95.41    95.35     100.58     108.20
# 64  2022   May       120.51    106.15  105.41   105.29     111.09     119.49
# 65  2022   Oct       106.31     97.43   96.72    96.63     101.94     109.66
# 66  2022   Sep       106.31     97.43   96.72    96.63     101.94     109.66
#
# ...

# %%
data[(data["date"]==2017) & (data["month"]=='Aug')]
# Out:
#    date month  Maharashtra   Haryana  Delhi  Gujarat  Karnataka  Telangana  \
# 0  2017   Aug        74.56     64.98   65.4    67.09      66.39      69.24
#
#    Rajasthan  Punjab  West_bengal  Tamil Nadu   Uttar Pradesh  Madhya Pradesh  \
# 0      67.93   70.32        68.56       67.71           68.63           71.99
#
#    Kerala  Assam  Bihar
# 0   69.06  68.03  69.78

# %%
data[(data["date"]==2018) & (data["month"]=='Aug')]
# Out:
#    date month  Maharashtra   Haryana  Delhi  Gujarat  Karnataka  Telangana  \
# 9  2018   Aug        83.76     76.52  76.31    75.68      78.77       80.9
#
#    Rajasthan  Punjab  West_bengal  Tamil Nadu   Uttar Pradesh  Madhya Pradesh  \
# 9      79.26   81.49         79.2       79.26           77.11           81.97
#
#    Kerala  Assam  Bihar
# 9   79.47  78.51  82.05

# %%
data[(data["date"]==2019) & (data["month"]=='Aug')]
# Out:
#     date month  Maharashtra   Haryana  Delhi  Gujarat  Karnataka  Telangana  \
# 21  2019   Aug        78.42     72.32   72.8    70.36      75.21      77.31
#
#     Rajasthan  Punjab  West_bengal  Tamil Nadu   Uttar Pradesh  \
# 21      76.72   72.59        75.44        75.6           72.04
#
#     Madhya Pradesh  Kerala  Assam  Bihar
# 21           77.95   76.06  72.37  76.37

# %%
data[(data["date"]==2020) & (data["month"]=='Aug')]
# Out:
#     date month  Maharashtra   Haryana  Delhi  Gujarat  Karnataka  Telangana  \
# 33  2020   Aug        87.19     78.18  80.43    78.08      83.04      83.49
#
#     Rajasthan  Punjab  West_bengal  Tamil Nadu   Uttar Pradesh  \
# 33      87.57   81.63         82.1       83.63           80.98
#
#     Madhya Pradesh  Kerala  Assam  Bihar
# 33           88.08   82.15   84.5  83.31

# %%
data[(data["date"]==2021) & (data["month"]=='Aug')]
# Out:
#     date month  Maharashtra   Haryana   Delhi  Gujarat  Karnataka  Telangana  \
# 45  2021   Aug       107.83     98.92  101.84    98.79     105.25     105.83
#
#     Rajasthan  Punjab  West_bengal  Tamil Nadu   Uttar Pradesh  \
# 45     108.71  102.85       102.08      102.49           98.92
#
#     Madhya Pradesh  Kerala  Assam   Bihar
# 45           110.2  103.82  97.64  104.25

# %%
data[(data["date"]==2022) & (data["month"]=='Aug')]
# Out:
#     date month  Maharashtra   Haryana  Delhi  Gujarat  Karnataka  Telangana  \
# 57  2022   Aug       106.31     97.43  96.72    96.63     101.94     109.66
#
#     Rajasthan  Punjab  West_bengal  Tamil Nadu   Uttar Pradesh  \
# 57     108.48   96.18       106.03      102.63           96.57
#
#     Madhya Pradesh  Kerala  Assam   Bihar
# 57          108.65  107.71  96.01  107.24

# %%
data[(data["date"]==2022) & (data["Maharashtra"]>80)]
# Out:
#     date month  Maharashtra   Haryana   Delhi  Gujarat  Karnataka  Telangana  \
# 56  2022   Apr       116.72    102.51  101.81   101.70     107.30     115.42
# 57  2022   Aug       106.31     97.43   96.72    96.63     101.94     109.66
# 58  2022   Dec       106.31     97.43   96.72    96.63     101.94     109.66
# 59  2022   Feb       109.98     95.27   95.41    95.35     100.58     108.20
# 60  2022   Jan       109.98     95.27   95.41    95.35     100.58     108.20
# 61  2022   Jul       111.35     97.43   96.72    96.63     101.94     109.66
# 62  2022   Jun        97.28     90.27   89.62    92.38      87.89      97.82
# 63  2022   Mar       109.98     95.27   95.41    95.35     100.58     108.20
# 64  2022   May       120.51    106.15  105.41   105.29     111.09     119.49
# 65  2022   Oct       106.31     97.43   96.72    96.63     101.94     109.66
# 66  2022   Sep       106.31     97.43   96.72    96.63     101.94     109.66
#
# ...

# %%
data[(data["date"]==2022) & (data["Maharashtra"]>89.094)]
# Out:
#     date month  Maharashtra   Haryana   Delhi  Gujarat  Karnataka  Telangana  \
# 56  2022   Apr       116.72    102.51  101.81   101.70     107.30     115.42
# 57  2022   Aug       106.31     97.43   96.72    96.63     101.94     109.66
# 58  2022   Dec       106.31     97.43   96.72    96.63     101.94     109.66
# 59  2022   Feb       109.98     95.27   95.41    95.35     100.58     108.20
# 60  2022   Jan       109.98     95.27   95.41    95.35     100.58     108.20
# 61  2022   Jul       111.35     97.43   96.72    96.63     101.94     109.66
# 62  2022   Jun        97.28     90.27   89.62    92.38      87.89      97.82
# 63  2022   Mar       109.98     95.27   95.41    95.35     100.58     108.20
# 64  2022   May       120.51    106.15  105.41   105.29     111.09     119.49
# 65  2022   Oct       106.31     97.43   96.72    96.63     101.94     109.66
# 66  2022   Sep       106.31     97.43   96.72    96.63     101.94     109.66
#
# ...

# %%
data[(data["date"]==2021) & (data["Kerala"]>89.049)]
# Out:
#     date month  Maharashtra   Haryana   Delhi  Gujarat  Karnataka  Telangana  \
# 44  2021   Apr        96.98     88.02   90.56    87.90      93.59      94.16
# 45  2021   Aug       107.83     98.92  101.84    98.79     105.25     105.83
# 46  2021   Dec       109.98     95.27   95.41    95.35     100.58     108.20
# 49  2021   Jul       104.90     95.97   98.81    95.86     102.11     102.69
# 50  2021   Jun       100.72     91.78   94.49    91.68      97.64      98.20
# 51  2021   Mar        97.57     88.61   91.17    88.49      94.22      94.79
# 52  2021   May        96.83     87.86   90.40    87.75      93.43      93.99
# 53  2021   Nov       115.50    106.62  109.69   106.53     113.56     114.12
# 54  2021   Oct       107.95     99.04  101.89    98.95     105.44     106.00
# 55  2021   Sep       107.39     98.48  101.34    98.39     104.84     105.40
#
#     Rajasthan  Punjab  West_bengal  Tamil Nadu   Uttar Pradesh  \
# ...

# %% [markdown]
# # **Graphical Representations**

# %% [markdown]
# # Bar chart

# %%
data_new.Maharashtra.nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Maharashtra")
plt.ylabel('year')
plt.xlabel('rate')
plt.grid(False)

# %% [markdown]
# # Heatmap for correlation  data

# %%
sns.heatmap(data.corr())
sns.set(rc={"figure.figsize":(7, 5)})
plt.show()
# Out:
# <ipython-input-760-a0d6098c7f02>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())

# %% [markdown]
# # Histogram

# %%
from matplotlib import pyplot as plt
data['Maharashtra'].plot(kind='hist', bins=20, title='Maharashtra',figsize=(5,5))
plt.grid(False)

# %%
from matplotlib import pyplot as plt
data[' Haryana'].plot(kind='hist', bins=20, title=' Haryana',figsize=(5,5))
plt.grid(False)

# %%
from matplotlib import pyplot as plt
data['Delhi'].plot(kind='hist', bins=20, title='Delhi',figsize=(5,5))
# plt.gca().spines[['top', 'right',]].set_visible(False)
plt.grid(False)

# %%
from matplotlib import pyplot as plt
data['Gujarat'].plot(kind='hist', bins=20, title='Gujarat',figsize=(5,5))
# plt.gca().spines[['top', 'right',]].set_visible(False)
plt.grid(False)

# %%
from matplotlib import pyplot as plt
data['Karnataka'].plot(kind='hist', bins=20, title='Karnataka',figsize=(5,5))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.grid(False)

# %%
from matplotlib import pyplot as plt
data['Telangana'].plot(kind='hist', bins=20, title='Telangana',figsize=(5,5))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.grid(False)

# %%
from matplotlib import pyplot as plt
data['Rajasthan'].plot(kind='hist', bins=20, title='Rajasthan',figsize=(5,5))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.grid(False)

# %% [markdown]
# # Line Chart

# %%
data_new.groupby(data_new['date']==2017).plot(x='month', y='Tamil Nadu',figsize=(5,5))
plt.grid(False)

# %%
data_new.groupby(data_new['date']==2018).plot(x='month', y='Tamil Nadu',figsize=(5,5))
plt.grid(False)

# %%
data_new.groupby(data_new['date']==2022).plot(x='month', y='Tamil Nadu',figsize=(5,5))
plt.grid(False)

# %% [markdown]
# # Pie Chart

# %%
data_new.groupby(data_new['date']==2022).plot(x='month', y='Kerala',kind='pie',figsize=(8, 8),autopct="%1.1f%%")
# Out:
# date
# False    Axes(0.1275,0.11;0.77x0.77)
# True     Axes(0.1275,0.11;0.77x0.77)
# dtype: object

# %%
data_new.groupby(data_new['date']==2021).plot(x='month', y='Kerala',kind='pie',figsize=(8, 8),autopct="%1.1f%%")
# Out:
# date
# False    Axes(0.1275,0.11;0.77x0.77)
# True     Axes(0.1275,0.11;0.77x0.77)
# dtype: object

# %%
data_new.groupby(data_new['date']==2020).plot(x='month', y='Kerala',kind='pie',figsize=(8, 8),autopct="%1.1f%%")
# Out:
# date
# False    Axes(0.1275,0.11;0.77x0.77)
# True     Axes(0.1275,0.11;0.77x0.77)
# dtype: object

# %% [markdown]
# # Scatter Plot

# %%
data_new.groupby(data_new['date']==2022).plot(x='month', y=' Haryana',kind='scatter',figsize=(5, 5))
plt.grid(False)

# %%
data_new.groupby(data_new['date']==2021).plot(x='month', y=' Haryana',kind='scatter',figsize=(5, 5))
plt.grid(False)

# %% [markdown]
# # Area Chart

# %%
data_new.groupby(data_new['date']==2022).plot(x='month', y='Karnataka',kind='area',figsize=(5, 5))
plt.grid(False)

# %%
data_new.groupby(data_new['date']==2021).plot(x='month', y='Karnataka',kind='area',figsize=(5, 5))
plt.grid(False)

# %% [markdown]
# # Box Plot

# %%
plt.boxplot(data_new['Delhi'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-749-05a4f041c68c> in <cell line: 1>()
# ----> 1 plt.boxplot(data_new['Delhi'],figsize=(5,5))
#
# TypeError: boxplot() got an unexpected keyword argument 'figsize'

# %%
plt.boxplot(data_new['Kerala'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x784b26a08340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x784b26a08880>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x784b26a080a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x784b26a08dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x784b26a09060>],
#  'means': []}

# %%
plt.boxplot(data_new['Tamil Nadu'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x784b2685d9c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x784b2685dde0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x784b2685d720>],
#  'medians': [<matplotlib.lines.Line2D at 0x784b2685e320>],
#  'fliers': [<matplotlib.lines.Line2D at 0x784b2685e5c0>],
#  'means': []}
